# %%
#'C:\\Users\\79151\\Downloads'
import os
import matplotlib

import matplotlib.pyplot as plt 

root = os.getcwd()
filename = os.path.join('C:\\Users\\79151\\', 'company_sales_data.csv')
filename
# Out:
# 'C:\\Users\\79151\\company_sales_data.csv'

# %%
import pandas as pd
data = pd.read_csv(filename)
months = data['month_number'].tolist()
total_profit = data['total_profit'].tolist()
facecream = data['facecream'].tolist()
facewash = data['facewash'].tolist()
toothpaste = data['toothpaste'].tolist()
bathingsoap = data['bathingsoap'].tolist()
shampoo = data['shampoo'].tolist()
moisturizer = data['moisturizer'].tolist()
total_units = data['total_units'].tolist()
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
#1. Прочитайте все данные о продажах продукта и покажите их с помощью многострочного графика

matplotlib.pyplot.rcParams['figure.figsize'] = [16, 11]
plt.plot(months, facecream, label = 'facecream')
plt.plot(months, facewash, label = 'facewash')
plt.plot(months, toothpaste, label = 'toothpaste')
plt.plot(months, bathingsoap, label = 'bathingsoap')
plt.plot(months, shampoo, label = 'shampoo')
plt.plot(months, moisturizer, label = 'moisturizer')
matplotlib.pyplot.legend(loc='upper left')
matplotlib.pyplot.rcParams['figure.figsize'] = [10, 7]

plt.xlabel('Months')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# 2. Прочитайте данные о продажах мыла для купания за все месяцы и покажите их с помощью столбчатой диаграммы.

plt.bar([i - 0.2 for i in months], facecream, label = 'facecream')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 3. Рассчитайте общие данные о продажах за год для каждого продукта и покажите их с помощью круговой диаграммы

labels = 'facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo', 'moisturizer'
sizes = [sum(facecream), sum(facewash), sum(toothpaste), sum(bathingsoap), sum(shampoo), sum(moisturizer)]
explode = [0 if j != max(sizes) else 0.05 for j in sizes]  
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')

plt.show()
